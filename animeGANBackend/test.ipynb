# %%
from KK import Model, base64toimage, image2base64
import requests
import PIL.Image
import cv2
import matplotlib.pyplot as plt
import numpy as np
image = requests.get("https://static.wikia.nocookie.net/harrypotter/images/9/97/Harry_Potter.jpg/revision/latest?cb=20140603201724", stream=True).raw
image = PIL.Image.open(image).convert("RGB")
image = image2base64(np.array(image))
model = Model()
image = model.predict(image)
image = np.array(image)
plt.imshow(image)
# Out:
# Using cache found in C:\Users\xcdtl/.cache\torch\hub\bryandlee_animegan2-pytorch_main
# Using cache found in C:\Users\xcdtl/.cache\torch\hub\bryandlee_animegan2-pytorch_main
